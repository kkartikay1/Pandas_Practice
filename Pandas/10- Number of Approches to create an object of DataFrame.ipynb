# %%
import pandas as pd
import numpy as np

# %%
a=10
# df=pd.DataFrame(a)
# print(df,type(df))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14552\2074791994.py in ?()
#       1 a=10
# ----> 2 df=pd.DataFrame(a)
#       3 print(df,type(df))
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
a=10
lst=list([a])
df=pd.DataFrame(lst)
print(df,type(df))
# Out:
#     0
# 0  10 <class 'pandas.core.frame.DataFrame'>

# %%
lst=[100,"Rossum",250.65,2+4j,"Python"]
df=pd.DataFrame(lst)
print(df,type(df))
# Out:
#         0
# 0     100
# 1  Rossum
# 2  250.65
# 3  (2+4j)
# 4  Python <class 'pandas.core.frame.DataFrame'>

# %%
lst=[[10,20,30,40],["Rossum","Travis","Hunter","Fighter"]]
df=pd.DataFrame(lst)
print(df,type(df))
# Out:
#         0       1       2        3
# 0      10      20      30       40
# 1  Rossum  Travis  Hunter  Fighter <class 'pandas.core.frame.DataFrame'>

# %%
lst=[[10,20,30,40],["Rossum","Travis","Hunter","Fighter"],[120.2,545.65,54.22,865.55]]
df=pd.DataFrame(lst)
print(df,type(df))
# Out:
#         0       1       2        3
# 0      10      20      30       40
# 1  Rossum  Travis  Hunter  Fighter
# 2   120.2  545.65   54.22   865.55 <class 'pandas.core.frame.DataFrame'>

# %%
lst=[[10,20,30,40],["Rossum","Travis","Hunter","Fighter"]]
df=pd.DataFrame(lst,columns=["Rec1","Rec2","Rec3","Rec4"])
print(df,type(df))
# Out:
#      Rec1    Rec2    Rec3     Rec4
# 0      10      20      30       40
# 1  Rossum  Travis  Hunter  Fighter <class 'pandas.core.frame.DataFrame'>

# %%
lst=[[10,20,30,40],["Rossum","Travis","Hunter","Fighter"]]
df=pd.DataFrame(lst,index=["Id","Name"],columns=["Rec1","Rec2","Rec3","Rec4"])
print(df,type(df))
# Out:
#         Rec1    Rec2    Rec3     Rec4
# Id        10      20      30       40
# Name  Rossum  Travis  Hunter  Fighter <class 'pandas.core.frame.DataFrame'>

# %%
st={100,200,300,400,500,200}
print(st,type(st))
# Out:
# {400, 100, 500, 200, 300} <class 'set'>

# %%
df=pd.DataFrame(st)
print(df,type(df))
# Out:
#      0
# 0  400
# 1  100
# 2  500
# 3  200
# 4  300 <class 'pandas.core.frame.DataFrame'>

# %%
lst={"ID":[10,20,30,40],"Name":["Rossum","Travis","Hunter","Fighter"],"Price":[120.2,545.65,54.22,865.55]}
print(lst,type(lst))
# Out:
# {'ID': [10, 20, 30, 40], 'Name': ['Rossum', 'Travis', 'Hunter', 'Fighter'], 'Price': [120.2, 545.65, 54.22, 865.55]} <class 'dict'>

# %%
for key,val in lst.items():
    print(key,"-->",val)
# Out:
# ID --> [10, 20, 30, 40]
# Name --> ['Rossum', 'Travis', 'Hunter', 'Fighter']
# Price --> [120.2, 545.65, 54.22, 865.55]

# %%
lst={"ID":[10,20,30,40],"Name":["Rossum","Travis","Hunter","Fighter"],"Price":[120.2,545.65,54.22,865.55]}
print(lst,type(lst))
print("="*50)
df=pd.DataFrame(lst)
print(df,type(df))
# Out:
# {'ID': [10, 20, 30, 40], 'Name': ['Rossum', 'Travis', 'Hunter', 'Fighter'], 'Price': [120.2, 545.65, 54.22, 865.55]} <class 'dict'>
# ...
#    ID     Name   Price
# 0  10   Rossum  120.20
# 1  20   Travis  545.65
# 2  30   Hunter   54.22
# 3  40  Fighter  865.55 <class 'pandas.core.frame.DataFrame'>

# %%
lst={"ID":[10,20,30,40],"Name":["Rossum","Travis","Hunter","Fighter"],"Price":[120.2,545.65,54.22,865.55]}
print(lst,type(lst))
print("="*50)
df=pd.DataFrame(lst,index=["ID1","ID2","ID3","ID4"])
print(df,type(df))
# Out:
# {'ID': [10, 20, 30, 40], 'Name': ['Rossum', 'Travis', 'Hunter', 'Fighter'], 'Price': [120.2, 545.65, 54.22, 865.55]} <class 'dict'>
# ...
#      ID     Name   Price
# ID1  10   Rossum  120.20
# ID2  20   Travis  545.65
# ID3  30   Hunter   54.22
# ID4  40  Fighter  865.55 <class 'pandas.core.frame.DataFrame'>

# %%
lst={10:"Python",20:"Java",30:"C#"}
print(lst,type(lst))
print("="*50)
df=pd.DataFrame(lst)
print(df,type(df))
# Out:
# {10: 'Python', 20: 'Java', 30: 'C#'} <class 'dict'>
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 print(lst,type(lst))
#       3 print("="*50)
# ----> 4 df=pd.DataFrame(lst)
#       5 print(df,type(df))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
lst={10:"Python",20:"Java",30:"C#"}
print(lst,type(lst))
print("="*50)
df=pd.DataFrame(lst,index=["Cources"])
print(df,type(df))
# Out:
# {10: 'Python', 20: 'Java', 30: 'C#'} <class 'dict'>
# ...
#              10    20  30
# Cources  Python  Java  C# <class 'pandas.core.frame.DataFrame'>

# %%
s=pd.Series([100,200,300,400,500])
print(s,type(s))
print("="*50)
df=pd.DataFrame(s)
print(df,type(df))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64 <class 'pandas.core.series.Series'>
# ...
#      0
# 0  100
# 1  200
# 2  300
# 3  400
# 4  500 <class 'pandas.core.frame.DataFrame'>

# %%
s=pd.Series([100,200,300,400,500])
print(s,type(s))
print("="*50)
df=pd.DataFrame(s,index=["ID1","ID2","ID3","ID4"],columns=["Values"])
print(df,type(df))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64 <class 'pandas.core.series.Series'>
# ...
#      Values
# ID1     NaN
# ID2     NaN
# ID3     NaN
# ID4     NaN <class 'pandas.core.frame.DataFrame'>

# %%
s=pd.Series([100,200,300,400,500],index=["ID1","ID2","ID3","ID4","ID5"])
print(s,type(s))
print("="*50)
df=pd.DataFrame(s,columns=["Values"])
print(df,type(df))
# Out:
# ID1    100
# ID2    200
# ID3    300
# ID4    400
# ID5    500
# dtype: int64 <class 'pandas.core.series.Series'>
# ...
#      Values
# ID1     100
# ID2     200
# ID3     300
# ID4     400
# ID5     500 <class 'pandas.core.frame.DataFrame'>

# %%
s=pd.Series([100,200,300,400,500])
print(s,type(s))
print("="*50)
df=pd.DataFrame(s,columns=["Values"])
print(df,type(df))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64 <class 'pandas.core.series.Series'>
# ...
#    Values
# 0     100
# 1     200
# 2     300
# 3     400
# 4     500 <class 'pandas.core.frame.DataFrame'>

# %%
s=pd.Series([100,200,300,400,500],index=["ID1","ID2","ID3","ID4","ID5"])
print(s,type(s))
print("="*50)
df=pd.DataFrame(s,columns=["Values1","Values2"])
print(df,type(df))
# Out:
# ID1    100
# ID2    200
# ID3    300
# ID4    400
# ID5    500
# dtype: int64 <class 'pandas.core.series.Series'>
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 4
#       2 print(s,type(s))
#       3 print("="*50)
# ----> 4 df=pd.DataFrame(s,columns=["Values1","Values2"])
#       5 print(df,type(df))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
# ...

# %%
s=np.array([100,200,300,400,500])
print(s,type(s))
print("="*50)
df=pd.DataFrame(s)
print(df,type(df))
# Out:
# [100 200 300 400 500] <class 'numpy.ndarray'>
# ...
#      0
# 0  100
# 1  200
# 2  300
# 3  400
# 4  500 <class 'pandas.core.frame.DataFrame'>

# %%
s=np.array([100,200,300,400,500])
print(s,type(s))
print("="*50)
df=pd.DataFrame(s,index=["ID1","ID2","ID3","ID4","ID5"])
print(df,type(df))
# Out:
# [100 200 300 400 500] <class 'numpy.ndarray'>
# ...
#        0
# ID1  100
# ID2  200
# ID3  300
# ID4  400
# ID5  500 <class 'pandas.core.frame.DataFrame'>

# %%
dic={"ID":[10,20,30,40],"Name":["Rossum","Travis","Hunter","Fighter"],"Price":[120.2,545.65,54.22,865.55]}
s=np.array(dic)
print(s,type(s))
print(s.ndim)
print(s.shape)
# Out:
# {'ID': [10, 20, 30, 40], 'Name': ['Rossum', 'Travis', 'Hunter', 'Fighter'], 'Price': [120.2, 545.65, 54.22, 865.55]} <class 'numpy.ndarray'>
# 0
# ()

# %%
dic={"ID":[10,20,30,40],"Name":["Rossum","Travis","Hunter","Fighter"],"Price":[120.2,545.65,54.22,865.55]}
s=np.array(dic)
print(s,type(s))
print("="*50)
df=pd.DataFrame(s)
print(df,type(df))
# Out:
# {'ID': [10, 20, 30, 40], 'Name': ['Rossum', 'Travis', 'Hunter', 'Fighter'], 'Price': [120.2, 545.65, 54.22, 865.55]} <class 'numpy.ndarray'>
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 5
#       3 print(s,type(s))
#       4 print("="*50)
# ----> 5 df=pd.DataFrame(s)
#       6 print(df,type(df))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
# ...

# %%
dic={"ID":[10,20,30,40],"Name":["Rossum","Travis","Hunter","Fighter"],"Price":[120.2,545.65,54.22,865.55]}
s=np.array(dic)
print(s,type(s))
print("="*50)
df=pd.DataFrame(s)
print(df,type(df))
