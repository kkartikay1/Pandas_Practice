# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([12,34,15,8,22,10,8,-4])
print(s)
# Out:
# 0    12
# 1    34
# 2    15
# 3     8
# 4    22
# 5    10
# 6     8
# 7    -4
# dtype: int64

# %%
s.sort_values(ascending=False,inplace=True)

# %%
s.head(2)
# Out:
# 1    34
# 4    22
# dtype: int64

# %%
s[:2]
# Out:
# 1    34
# 4    22
# dtype: int64

# %%
print(s)
# Out:
# 1    34
# 4    22
# 2    15
# 0    12
# 5    10
# 3     8
# 6     8
# 7    -4
# dtype: int64

# %%
s.tail(2)
# Out:
# 6    8
# 7   -4
# dtype: int64

# %%
s[-2:]
# Out:
# 6    8
# 7   -4
# dtype: int64

# %%
s=pd.Series([12,34,15,8,22,10,8,-4])
print(s)
# Out:
# 0    12
# 1    34
# 2    15
# 3     8
# 4    22
# 5    10
# 6     8
# 7    -4
# dtype: int64

# %%
s.nlargest()
# Out:
# 1    34
# 4    22
# 2    15
# 0    12
# 5    10
# dtype: int64

# %%
s=pd.Series([12,34,15,8,22,10,8,-4])
print(s.nlargest(2))
# Out:
# 1    34
# 4    22
# dtype: int64

# %%
s=pd.Series([12,34,15,8,22,10,8,-4])
print("Smallest\n",s.nsmallest())
# Out:
# Smallest
#  7    -4
# 3     8
# 6     8
# 5    10
# 0    12
# dtype: int64

# %%
s=pd.Series([12,34,15,8,22,10,8,-4])
print("Smallest\n",s.nsmallest(3))
# Out:
# Smallest
#  7   -4
# 3    8
# 6    8
# dtype: int64

# %%
s=pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print("Sum=",s.sum())
print("Product=",s.prod())
print("Mean=",s.mean())
print("Median=",s.median())
# Out:
# Sum= 150
# Product= 12000000
# Mean= 30.0
# Median= 30.0

# %%
 s.agg(["sum","prod","mean","median"])
# Out:
# sum            150.0
# prod      12000000.0
# mean            30.0
# median          30.0
# dtype: float64

# %%
s=pd.Series([10,20,None,40,50,None])
s.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
s.isna().sum()
# Out:
# np.int64(2)
