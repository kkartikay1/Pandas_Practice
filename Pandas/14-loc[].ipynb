# %%
import pandas as pd
import numpy as np

# %%
# Get the data from Sutdent.csv into Datafram
df=pd.read_csv("D:\\Akash\\Python\\KVR-PYTHON-PART-1\\PANDAS\\NOTES\\peoples.csv")
print("="*50)
print("{}".format(df))
print("="*50)
# Out:
# ...
#     CID      CNAME  STATE DSG
# 0   100      SUSMA     TS  SE
# 1   200   SAGATIKA     AP  SE
# 2   300      LAXMI     TS  TL
# 3   400     ROSSUM     AP  TL
# 4   500     NARESH  DELHI  PM
# 5   600      VINAY  DELHI   M
# 6   700  TEJASWANI     AP  SE
# 7   800     FAZINA     TS  PM
# 8   900    SANSKAR  DELHI  SE
# 9   750        KVR     AP  PM
# 10  650      RADHA   BANG  TL
# 11  550    MOUNIKA     AP  PM
# 12  350    SIRISHA     TS  HR
# 13  150    MADHVAI     AP  HR
# 14  450   JAYSHREE   BANG  HR
# 15  950     ANJALI     AP  HR
# 16  250      KOMAL     TS  TL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CID     17 non-null     int64
#  1   CNAME   17 non-null     object
#  2   STATE   17 non-null     object
#  3   DSG     17 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 676.0+ bytes

# %%
# Syntax 1: DataFrameObject.loc[row_number]
# get 7th record
df.loc[7]
# Out:
# CID         800
# CNAME    FAZINA
# STATE        TS
# DSG          PM
# Name: 7, dtype: object

# %%
df.loc[3]
# Out:
# CID         400
# CNAME    ROSSUM
# STATE        AP
# DSG          TL
# Name: 3, dtype: object

# %%
df.loc[30]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 30 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.loc[30]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
# Syntax 2: DataFrameObject.loc[row_number,[Column_name]]
# get 7th record name
df.loc[7,["CNAME"]]
# Out:
# CNAME    FAZINA
# Name: 7, dtype: object

# %%
# get 2th record name
df.loc[2,["CNAME"]]
# Out:
# CNAME    LAXMI
# Name: 2, dtype: object

# %%
df.loc[2,["CNAME","EXP"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.loc[2,["CNAME","EXP"]]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# ...

# %%
# Syntax 3: DataFrameObject.loc[RowBegainIndex:RowEndIndex:Step]
# get 3th to 7th record name
df.loc[3:7]

# %%
df.loc[::2]
# Out:
#     CID      CNAME  STATE DSG
# 0   100      SUSMA     TS  SE
# 2   300      LAXMI     TS  TL
# 4   500     NARESH  DELHI  PM
# 6   700  TEJASWANI     AP  SE
# 8   900    SANSKAR  DELHI  SE
# 10  650      RADHA   BANG  TL
# 12  350    SIRISHA     TS  HR
# 14  450   JAYSHREE   BANG  HR
# 16  250      KOMAL     TS  TL

# %%
# Syntax 4: DataFrameObject.loc[owBegainIndex:RowEndIndex:Step,[Column_name]]
# get 3rd to 7th record name
df.loc[3:7,["CNAME","EXP"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Syntax 4: DataFrameObject.loc[owBegainIndex:RowEndIndex:Step,[Column_name]]
#       2 # get 3rd to 7th record name
# ----> 3 df.loc[3:7,["CNAME","EXP"]]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# ...

# %%
print(df)

# %%
# 
df.loc[4:6,"CNAME"::2]
# Out:
#        CNAME DSG
# 4     NARESH  PM
# 5      VINAY   M
# 6  TEJASWANI  SE

# %%
df.loc[2:6,"CNAME"::1]
# Out:
#        CNAME  STATE DSG
# 2      LAXMI     TS  TL
# 3     ROSSUM     AP  TL
# 4     NARESH  DELHI  PM
# 5      VINAY  DELHI   M
# 6  TEJASWANI     AP  SE

# %%
df.loc[2:6,"CNAME":]
# Out:
#        CNAME  STATE DSG
# 2      LAXMI     TS  TL
# 3     ROSSUM     AP  TL
# 4     NARESH  DELHI  PM
# 5      VINAY  DELHI   M
# 6  TEJASWANI     AP  SE

# %%
df.loc[2:6,"CID":"EXP"]

# %%
df.loc[2:6,::-1]

# %%
for name in df["CNAME"]:
    print(name[0:2])
