# %%
import pandas as pd
import numpy as np

# %%
d={"First":[100,200,300,np.nan],"Second":[150,np.nan,250,np.nan],
  "Third":[np.nan,250,120,100]}
print(d,type(d))
# Out:
# {'First': [100, 200, 300, nan], 'Second': [150, nan, 250, nan], 'Third': [nan, 250, 120, 100]} <class 'dict'>

# %%
for k,v in d.items():
    print(k,"--->",v)
# Out:
# First ---> [100, 200, 300, nan]
# Second ---> [150, nan, 250, nan]
# Third ---> [nan, 250, 120, 100]

# %%
df=pd.DataFrame(d)
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
# Find Missing Value using isnull()
# Syntax : DataFrameobj.isnull()
df.isnull()
# Out:
#    First  Second  Third
# 0  False   False   True
# 1  False    True  False
# 2  False   False  False
# 3   True    True  False

# %%
len(df.isnull())
# Out:
# 4

# %%
df.isnull().sum()
# Out:
# First     1
# Second    2
# Third     1
# dtype: int64

# %%
df.isnull().count().nunique()
# Out:
# 1

# %%
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
df.notnull()
# Out:
#    First  Second  Third
# 0   True    True  False
# 1   True   False   True
# 2   True    True   True
# 3  False   False   True

# %%
# print("Print Not null; Values=",len(df.notnull()))
print("Print Not null; Values=",(df.size-len(df.notnull())))
print("Print  null; Values=",len(df.isnull()))
print("Print Not null; Values=",len(df.notnull()))
# Out:
# Print Not null; Values= 2
# Print  null; Values= 1
# Print Not null; Values= 1

# %%
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
df.isnull()
# Out:
#    First  Second  Third
# 0  False   False   True
# 1  False    True  False
# 2  False   False  False
# 3   True    True  False

# %%
# Fill nan values wiith 0
# to fill nan values with 0, we uses fillna()
# syntax: df.fillna(value)

# %%
df.fillna(0)
# Out:
#    First  Second  Third
# 0  100.0   150.0    0.0
# 1  200.0     0.0  250.0
# 2  300.0   250.0  120.0
# 3    0.0     0.0  100.0

# %%
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
df=df.fillna(0)

# %%
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    0.0
# 1  200.0     0.0  250.0
# 2  300.0   250.0  120.0
# 3    0.0     0.0  100.0

# %%
d={"First":[100,200,300,np.nan],"Second":[150,np.nan,250,np.nan],
  "Third":[np.nan,250,120,100]}
df=pd.DataFrame(d)
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
df.fillna(0.0,inplace=True)
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    0.0
# 1  200.0     0.0  250.0
# 2  300.0   250.0  120.0
# 3    0.0     0.0  100.0

# %%
d={"First":[100,200,300,np.nan],"Second":[150,np.nan,250,np.nan],
  "Third":[np.nan,250,120,100]}
df=pd.DataFrame(d)
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
# Fill Nan values with 5.0
df.fillna(5.0,inplace=True)
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    5.0
# 1  200.0     5.0  250.0
# 2  300.0   250.0  120.0
# 3    5.0     5.0  100.0

# %%
d={"First":[100,200,300,np.nan],"Second":[150,np.nan,250,np.nan],
  "Third":[np.nan,250,120,100]}
df=pd.DataFrame(d)
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
# Fill nan values wiith 0
# to fill nan values with 0, we can s=aslo use replace(to_replace,value)
# syntax: df.replace(to_replace,value)

# %%
df.replace(to_replace=np.nan,value=0.0)
# Out:
#    First  Second  Third
# 0  100.0   150.0    0.0
# 1  200.0     0.0  250.0
# 2  300.0   250.0  120.0
# 3    0.0     0.0  100.0

# %%
d={"First":[100,200,300,np.nan],"Second":[150,np.nan,250,np.nan],
  "Third":[np.nan,250,120,100]}
df=pd.DataFrame(d)
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
# Drop Nan Values from DataFrameobj
df.dropna()
# Out:
#    First  Second  Third
# 2  300.0   250.0  120.0

# %%
print(df)
# Out:
#    First  Second  Third
# 0  100.0   150.0    NaN
# 1  200.0     NaN  250.0
# 2  300.0   250.0  120.0
# 3    NaN     NaN  100.0

# %%
# Drop Nan Values from DataFrameobj
df.dropna(inplace=True)

# %%
print(df)
# Out:
#    First  Second  Third
# 2  300.0   250.0  120.0
