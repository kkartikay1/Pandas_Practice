# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\\Akash\\Python\\KVR-PYTHON-PART-1\\PANDAS\\googleplaystore.csv")
print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pd.set_option("display.max_columns",None)
df=pd.read_csv("D:\\Akash\\Python\\KVR-PYTHON-PART-1\\PANDAS\\googleplaystore.csv")
print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# 1 Display First five Row
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# 1 Display First 3 Row
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
# 2 Display last five Row
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# 2 Display last 3 Row
df.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %%
# 3 Find Shape of Our DataSate (Number of Rows and Number of columns)
df.shape
# Out:
# (10841, 13)

# %%
# 3 Find Shape of Our DataSate (Number of Rows and Number of columns)
df.shape
print("Number of Apps =",df.shape[0])
print("Number of columns in each app=",df.shape[1])
# Out:
# Number of Apps = 10841
# Number of columns in each app= 13

# %%
# Display the Column Name the all the apps
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# App
# Category
# Rating
# Reviews
# Size
# Installs
# Type
# Price
# Content Rating
# Genres
# Last Updated
# Current Ver
# Android Ver

# %%
# 4 Get information about our DataSet 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# 5 Get Overall Statistics About THe DataFrame
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# 5 Get Overall Statistics About THe DataFrame
df.describe(include='all') # Give Descriptive Statical Information of al Columns
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
# 6 Total No. of Astrology app 
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["App"]
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
df.loc[df["App"]=='Astrology']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df["App"].str.contains('Astrology')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840     True
# Name: App, Length: 10841, dtype: bool

# %%
df[df["App"].str.contains('Astrology')]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#       Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570   161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592     2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840  398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 1570   June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592   July 26, 2018               4.2.1        4.0.3 and up
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
df[df["App"].str.contains('Astrology',case=False)]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#       Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570   161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592     2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840  398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 1570   June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592   July 26, 2018               4.2.1        4.0.3 and up
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
x=len(df[df["App"].str.contains('Astrology',case=False)])
print("Number Of Apps Contains a word Astrology =",x)
# Out:
# Number Of Apps Contains a word Astrology = 3

# %%
# 7 Find Average App Rating
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
avr=df['Rating'].mean()
print("Average App Rating Google Play Store=",avr)
# Out:
# Average App Rating Google Play Store= 4.193338315362443

# %%
# 8 Find The Unique Category
df['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
# 8 Find The Unique Category
print("Total No. of Unique Category",df['Category'].nunique())
# Out:
# Total No. of Unique Category 34

# %%
# 9 Find Whic Category Higest getting Average Ratting
#    1Group the Category
for gn, gninfo in df.groupby('Category'):
    print("Group Name :",gn)
    print("Group Info :\n",gninfo)
# Out:
# Group Name : 1.9
# Group Info :
#                                             App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN
# Group Name : ART_AND_DESIGN
# Group Info :
#                                                      App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# ...

# %%
# 9 Find Whic Category Higest getting Average Ratting
# 2  Get the Rating of Every Category
for ra in df.groupby('Category')["Rating"]:
    print(ra)
# Out:
# ('1.9', 10472    19.0
# Name: Rating, dtype: float64)
# ('ART_AND_DESIGN', 0       4.1
# 1       3.9
# 2       4.7
# 3       4.5
# 4       4.3
#        ...
# 7174    NaN
# 8679    4.2
# 8712    4.3
# 8871    NaN
# 8888    5.0
# Name: Rating, Length: 65, dtype: float64)
# ('AUTO_AND_VEHICLES', 49       4.2
# 50       4.0
# 51       3.8
# 52       4.6
# 53       3.9
#         ...
# 10137    2.1
# 10345    3.9
# 10486    4.6
# 10764    NaN
# 10811    NaN
# Name: Rating, Length: 85, dtype: float64)
# ('BEAUTY', 98       4.7
# 99       4.9
# 100      4.7
# 101      3.9
# 102      3.9
# 103      4.2
# 104      4.6
# 105      4.3
# 106      4.7
# 107      4.7
# 108      4.8
# 109      4.2
# 110      4.3
# 111      4.5
# 112      4.1
# 113      NaN
# 114      4.2
# 115      4.5
# 116      4.4
# 117      4.0
# 118      4.1
# 119      4.1
# 120      4.4
# 121      4.6
# 122      4.5
# 123      NaN
# 124      3.9
# 125      4.4
# 126      NaN
# 127      4.6
# 128      3.8
# 129      NaN
# ...

# %%
# 9 Find Whic Category Higest getting Average Ratting
#  3 Find the Mean of Rating of every Category
df.groupby('Category')["Rating"].mean()
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %%
# 9 Find Whic Category Higest getting Average Ratting
#  4 Find the Higet Average Rating 
df.groupby('Category')["Rating"].mean().sort_values()
# Out:
# Category
# DATING                  3.970769
# TOOLS                   4.047411
# MAPS_AND_NAVIGATION     4.051613
# VIDEO_PLAYERS           4.063750
# LIFESTYLE               4.094904
# TRAVEL_AND_LOCAL        4.109292
# BUSINESS                4.121452
# ENTERTAINMENT           4.126174
# FINANCE                 4.131889
# NEWS_AND_MAGAZINES      4.132189
# COMICS                  4.155172
# COMMUNICATION           4.158537
# FOOD_AND_DRINK          4.166972
# LIBRARIES_AND_DEMO      4.178462
# MEDICAL                 4.189143
# AUTO_AND_VEHICLES       4.190411
# PHOTOGRAPHY             4.192114
# FAMILY                  4.192272
# HOUSE_AND_HOME          4.197368
# PRODUCTIVITY            4.211396
# SPORTS                  4.223511
# WEATHER                 4.244000
# SOCIAL                  4.255598
# SHOPPING                4.259664
# HEALTH_AND_FITNESS      4.277104
# BEAUTY                  4.278571
# GAME                    4.286326
# PARENTING               4.300000
# ...

# %%
df.groupby('Category')["Rating"].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
# 10 Find the total number App having 5 Star Rating Apps
# 0 Find Column Name
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# 10 Find the total number App having 5 Star Rating Apps
# 1 Find The Rating Values
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
# 10 Find the total number App having 5 Star Rating Apps
# 2 Find The Rating Values is Equale to 5
df['Rating']==5
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837     True
# 10838    False
# 10839    False
# 10840    False
# Name: Rating, Length: 10841, dtype: bool

# %%
# 10 Find the total number App having 5 Star Rating Apps
# 3 Get the app name passing to boolean values to DataFrame
df[df['Rating']==5]
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
# 10 Find the total number App having 5 Star Rating Apps
# 4 Get Total Number of App names having 5 Star Rating
len(df[df['Rating']==5])
# Out:
# 274

# %%
# 11 Find The Average Values of Reviews
df["Reviews"].dtype
# Out:
# dtype('O')

# %%
# 11 Find The Average Values of Reviews
  # Covert Dtype 
df["Reviews"].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 3
#       1 # 11 Find The Average Values of Reviews
#       2   # Covert Dtype
# ----> 3 df["Reviews"].astype("float")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# 11 Find The Average Values of Reviews
  # Find the App reviews values is 3.0M
df[df["Reviews"]=='3.0M']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# 11 Find The Average Values of Reviews
  # Replace the values 3.0M to 3.0
df["Reviews"]=df["Reviews"].replace('3.0M',3.0)
print(df["Reviews"])
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
# 11 Find The Average Values of Reviews
  # Covert Dtype (O) to float 
df["Reviews"]=df["Reviews"].astype("float")

# %%
df["Reviews"].dtype
# Out:
# dtype('float64')

# %%
# 11 Find The Average Values of Reviews
# Now to get Average reviews 
df["Reviews"].mean()
# Out:
# np.float64(444111.9265750392)

# %%
# 12 Find Total Niumber of free app and Paid app
df["Type"]
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10841, dtype: object

# %%
# 12 Find Total Niumber of free app and Paid app
# free
df[df["Type"]=='Free']
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# 12 Find Total Niumber of free app and Paid app
# Paid
df[df["Type"]=='Paid']
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating Reviews                Size  Installs  Type   Price  \
# ...

# %%
# 12 Find Total Niumber of free app and Paid app
# free
df["Type"].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
# 13 Find Which App has Maximum Reviews
df["Reviews"].max()
# Out:
# '9992'

# %%
# 13 Find Which App has Maximum Reviews
# Gets the complete app details in Bollean
df["Reviews"].max()==df["Reviews"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Reviews, Length: 10841, dtype: bool

# %%
# 13 Find Which App has Maximum Reviews
# Gets the complete app details
df[df["Reviews"].max()==df["Reviews"]]
# Out:
#                          App Category  Rating Reviews Size    Installs  Type  \
# 2989  GollerCepte Live Score   SPORTS     4.2    9992  31M  1,000,000+  Free
#
#      Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 2989     0       Everyone  Sports  May 23, 2018         6.5  4.1 and up

# %%
# 13 Find Which App has Maximum Reviews
# Gets app name
df[df["Reviews"].max()==df["Reviews"]]["App"]
# Out:
# 2989    GollerCepte Live Score
# Name: App, dtype: object

# %%
# 14 Find the top 5 app name having higest Review
df["Reviews"].sort_values().tail().index
# Out:
# Index([3049, 2723, 2705, 4970, 2989], dtype='int64')

# %%
# 14 Find the top 5 app name having higest Review
df.iloc[df["Reviews"].sort_values().tail().index]
# Out:
#                                     App  Category  Rating Reviews Size  \
# 3049  US Open Tennis Championships 2018    SPORTS     4.0    9971  33M
# 2723                SnipSnap Coupon App  SHOPPING     4.2    9975  18M
# 2705                SnipSnap Coupon App  SHOPPING     4.2    9975  18M
# 4970       Ad Block REMOVER - NEED ROOT     TOOLS     3.3     999  91k
# 2989             GollerCepte Live Score    SPORTS     4.2    9992  31M
#
#         Installs  Type Price Content Rating    Genres       Last Updated  \
# 3049  1,000,000+  Free     0       Everyone    Sports       June 5, 2018
# 2723  1,000,000+  Free     0       Everyone  Shopping   January 22, 2018
# 2705  1,000,000+  Free     0       Everyone  Shopping   January 22, 2018
# 4970    100,000+  Free     0       Everyone     Tools  December 17, 2013
# 2989  1,000,000+  Free     0       Everyone    Sports       May 23, 2018
#
#      Current Ver Android Ver
# 3049         7.1  5.0 and up
# 2723         1.4  4.3 and up
# ...

# %%
# 14 Find the top 5 app name having higest Review
df.iloc[df["Reviews"].sort_values().tail().index]["App"]
# Out:
# 3049    US Open Tennis Championships 2018
# 2723                  SnipSnap Coupon App
# 2705                  SnipSnap Coupon App
# 4970         Ad Block REMOVER - NEED ROOT
# 2989               GollerCepte Live Score
# Name: App, dtype: object

# %%
# 15 Find the Average Rating of Free and Paid Apps
df["Type"]
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10841, dtype: object

# %%
for gp,gpinfo in df.groupby("Type")["Rating"]:
    if(gp=="Free" or gp=="Paid"):
        print("Group  Name :",gp)
        print("Group Info :",gpinfo.mean())
# Out:
# Group  Name : Free
# Group Info : 4.186202546163551
# Group  Name : Paid
# Group Info : 4.26661514683153

# %%
# 16 Find Top 5 Apps Having Maximum Installs
df["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
# 16 Find Top 5 Apps Having Maximum Installs
# Convert Dtype 
# df["Installs"].astype("int")
df["Installs_1"]=df["Installs"].str.replace(",","")
df["Installs_1"]=df["Installs_1"].str.replace("+","")

# %%
df["Installs_1"]
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs_1, Length: 10841, dtype: object

# %%
df["Installs_1"].dtype
# Out:
# dtype('O')

# %%
df[df["Installs_1"]=="Free"]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Installs_1
# 10472       1.0.19  4.0 and up         NaN       Free

# %%
df["Installs_1"]=df["Installs_1"].str.replace("Free","0")

# %%
df["Installs_1"]
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs_1, Length: 10841, dtype: object

# %%
df["Installs_1"]=df["Installs_1"].astype("int")
print(df["Installs_1"])
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs_1, Length: 10841, dtype: int64

# %%
df["Installs_1"].sort_values().tail()
# Out:
# 335     1000000000
# 336     1000000000
# 451     1000000000
# 1917    1000000000
# 152     1000000000
# Name: Installs_1, dtype: int64

# %%
df.iloc[df["Installs_1"].sort_values().tail().index]
# Out:
#                                            App             Category  Rating  \
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                         WhatsApp Messenger        COMMUNICATION     4.4
# 451                                      Gmail        COMMUNICATION     4.3
# 1917                            Subway Surfers                 GAME     4.5
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
#
#        Reviews                Size        Installs  Type Price Content Rating  \
# 335   56642847  Varies with device  1,000,000,000+  Free     0       Everyone
# 336   69119316  Varies with device  1,000,000,000+  Free     0       Everyone
# 451    4604483  Varies with device  1,000,000,000+  Free     0       Everyone
# 1917  27725352                 76M  1,000,000,000+  Free     0   Everyone 10+
# 152    1433233  Varies with device  1,000,000,000+  Free     0           Teen
#
# ...

# %%
df.iloc[df["Installs_1"].sort_values().tail().index][["App","Installs"]]
# Out:
#                                            App        Installs
# 335   Messenger – Text and Video Chat for Free  1,000,000,000+
# 336                         WhatsApp Messenger  1,000,000,000+
# 451                                      Gmail  1,000,000,000+
# 1917                            Subway Surfers  1,000,000,000+
# 152                          Google Play Books  1,000,000,000+
