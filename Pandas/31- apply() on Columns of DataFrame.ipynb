# %%
import numpy as np
import pandas as pd

# %%
a=np.array([10,20,30,40])
print(a,type(a))
# Out:
# [10 20 30 40] <class 'numpy.ndarray'>

# %%
np.sum(a)
# Out:
# np.int64(100)

# %%
df=pd.DataFrame([[10,11,12],[20,21,22]],columns=['a','b','c'])
print(df)
# Out:
#     a   b   c
# 0  10  11  12
# 1  20  21  22

# %%
df.apply(np.sum)
# Out:
# a    30
# b    32
# c    34
# dtype: int64

# %%
df.apply(np.prod)
# Out:
# a    200
# b    231
# c    264
# dtype: int64

# %%
print(df)
df.apply(np.sum,axis=1)
# Out:
#     a   b   c
# 0  10  11  12
# 1  20  21  22
# 0    33
# 1    63
# dtype: int64

# %%
print(df)
df.apply(np.sum,axis=0)
# Out:
#     a   b   c
# 0  10  11  12
# 1  20  21  22
# a    30
# b    32
# c    34
# dtype: int64

# %%
# Apply User Define Function
df=pd.DataFrame([[10,11,12],[20,21,22]],columns=['a','b','c'])
print(df)
print("==========================")
def addex(x):
    return x*2
print(df.apply(addex))
# Out:
#     a   b   c
# 0  10  11  12
# 1  20  21  22
# ...
#     a   b   c
# 0  20  22  24
# 1  40  42  44

# %%
df=pd.DataFrame([["Chetan",103,'Math',75],["Divya",104,'Science',80],["Divya",105,"Math",92]],
                columns=["Name","Roll","Subject","Marks"])
print(df)
# Out:
#      Name  Roll  Subject  Marks
# 0  Chetan   103     Math     75
# 1   Divya   104  Science     80
# 2   Divya   105     Math     92

# %%
df["Name"]=df["Name"].apply(lambda x:x.upper())

# %%
print(df)
# Out:
#      Name  Roll  Subject  Marks
# 0  CHETAN   103     Math     75
# 1   DIVYA   104  Science     80
# 2   DIVYA   105     Math     92
