# %%
import pandas as pd

# %%
# Get Employee Data set into DataFrame
df=pd.read_csv("D:\\Akash\\Python\\KVR-PYTHON-PART-1\\PANDAS\\NOTES\\peoples.csv")
print(df)
# Out:
#     CID      CNAME  STATE DSG
# 0   100      SUSMA     TS  SE
# 1   200   SAGATIKA     AP  SE
# 2   300      LAXMI     TS  TL
# 3   400     ROSSUM     AP  TL
# 4   500     NARESH  DELHI  PM
# 5   600      VINAY  DELHI   M
# 6   700  TEJASWANI     AP  SE
# 7   800     FAZINA     TS  PM
# 8   900    SANSKAR  DELHI  SE
# 9   750        KVR     AP  PM
# 10  650      RADHA   BANG  TL
# 11  550    MOUNIKA     AP  PM
# 12  350    SIRISHA     TS  HR
# 13  150    MADHVAI     AP  HR
# 14  450   JAYSHREE   BANG  HR
# 15  950     ANJALI     AP  HR
# 16  250      KOMAL     TS  TL

# %%
df.columns
# Out:
# Index(['CID', 'CNAME', 'STATE', 'DSG'], dtype='object')

# %%
df["STATE"]
# Out:
# 0        TS
# 1        AP
# 2        TS
# 3        AP
# 4     DELHI
# 5     DELHI
# 6        AP
# 7        TS
# 8     DELHI
# 9        AP
# 10     BANG
# 11       AP
# 12       TS
# 13       AP
# 14     BANG
# 15       AP
# 16       TS
# Name: STATE, dtype: object

# %%
df["STATE"]=="AP"
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# Name: STATE, dtype: bool

# %%
df[df["STATE"]=="AP"]
# Out:
#     CID      CNAME STATE DSG
# 1   200   SAGATIKA    AP  SE
# 3   400     ROSSUM    AP  TL
# 6   700  TEJASWANI    AP  SE
# 9   750        KVR    AP  PM
# 11  550    MOUNIKA    AP  PM
# 13  150    MADHVAI    AP  HR
# 15  950     ANJALI    AP  HR

# %%
df.loc[df["STATE"]=="AP"]
# Out:
#     CID      CNAME STATE DSG
# 1   200   SAGATIKA    AP  SE
# 3   400     ROSSUM    AP  TL
# 6   700  TEJASWANI    AP  SE
# 9   750        KVR    AP  PM
# 11  550    MOUNIKA    AP  PM
# 13  150    MADHVAI    AP  HR
# 15  950     ANJALI    AP  HR

# %%
df.loc[df["STATE"]=="AP"]["CNAME"]
# Out:
# 1      SAGATIKA
# 3        ROSSUM
# 6     TEJASWANI
# 9           KVR
# 11      MOUNIKA
# 13      MADHVAI
# 15       ANJALI
# Name: CNAME, dtype: object

# %%
len(df.loc[df["STATE"]=="AP"])
# Out:
# 7

# %%
# DataFrameobj.loc[(compund condition),["Col Name"]]=Expression
df.loc[df["STATE"]=="AP",["STATE"]]="Andhara Pradesh"

# %%
print(df)
# Out:
#     CID      CNAME            STATE DSG
# 0   100      SUSMA               TS  SE
# 1   200   SAGATIKA  Andhara Pradesh  SE
# 2   300      LAXMI               TS  TL
# 3   400     ROSSUM  Andhara Pradesh  TL
# 4   500     NARESH            DELHI  PM
# 5   600      VINAY            DELHI   M
# 6   700  TEJASWANI  Andhara Pradesh  SE
# 7   800     FAZINA               TS  PM
# 8   900    SANSKAR            DELHI  SE
# 9   750        KVR  Andhara Pradesh  PM
# 10  650      RADHA             BANG  TL
# 11  550    MOUNIKA  Andhara Pradesh  PM
# 12  350    SIRISHA               TS  HR
# 13  150    MADHVAI  Andhara Pradesh  HR
# 14  450   JAYSHREE             BANG  HR
# 15  950     ANJALI  Andhara Pradesh  HR
# 16  250      KOMAL               TS  TL

# %%
df.columns
# Out:
# Index(['CID', 'CNAME', 'STATE', 'DSG'], dtype='object')

# %%
df.loc[df["DSG"]=="SE"]
# Out:
#    CID      CNAME            STATE DSG
# 0  100      SUSMA               TS  SE
# 1  200   SAGATIKA  Andhara Pradesh  SE
# 6  700  TEJASWANI  Andhara Pradesh  SE
# 8  900    SANSKAR            DELHI  SE

# %%
df.loc[(df["DSG"]=="SE") & (df["STATE"]=="TS")]
# Out:
#    CID  CNAME STATE DSG
# 0  100  SUSMA    TS  SE

# %%
df.loc[(df["DSG"]=="SE") & (df["STATE"]=="TS"),["DSG"]]="SR. SE"
print(df)
# Out:
#     CID      CNAME            STATE     DSG
# 0   100      SUSMA               TS  SR. SE
# 1   200   SAGATIKA  Andhara Pradesh      SE
# 2   300      LAXMI               TS      TL
# 3   400     ROSSUM  Andhara Pradesh      TL
# 4   500     NARESH            DELHI      PM
# 5   600      VINAY            DELHI       M
# 6   700  TEJASWANI  Andhara Pradesh      SE
# 7   800     FAZINA               TS      PM
# 8   900    SANSKAR            DELHI      SE
# 9   750        KVR  Andhara Pradesh      PM
# 10  650      RADHA             BANG      TL
# 11  550    MOUNIKA  Andhara Pradesh      PM
# 12  350    SIRISHA               TS      HR
# 13  150    MADHVAI  Andhara Pradesh      HR
# 14  450   JAYSHREE             BANG      HR
# 15  950     ANJALI  Andhara Pradesh      HR
# 16  250      KOMAL               TS      TL

# %%
df.loc[((df["DSG"]=="SR. SE") & (df["STATE"]=="TS")),["STATE","DSG"]]=\
["Telangana","Pythonist"]

# %%
print(df)
# Out:
#     CID      CNAME            STATE        DSG
# 0   100      SUSMA        Telangana  Pythonist
# 1   200   SAGATIKA  Andhara Pradesh         SE
# 2   300      LAXMI               TS         TL
# 3   400     ROSSUM  Andhara Pradesh         TL
# 4   500     NARESH            DELHI         PM
# 5   600      VINAY            DELHI          M
# 6   700  TEJASWANI  Andhara Pradesh         SE
# 7   800     FAZINA               TS         PM
# 8   900    SANSKAR            DELHI         SE
# 9   750        KVR  Andhara Pradesh         PM
# 10  650      RADHA             BANG         TL
# 11  550    MOUNIKA  Andhara Pradesh         PM
# 12  350    SIRISHA               TS         HR
# 13  150    MADHVAI  Andhara Pradesh         HR
# 14  450   JAYSHREE             BANG         HR
# 15  950     ANJALI  Andhara Pradesh         HR
# 16  250      KOMAL               TS         TL

# %%
# Find the nu,ber of People and their name who are living in BANG
df.loc[df["STATE"]=="BANG"]
# Out:
#     CID     CNAME STATE DSG
# 10  650     RADHA  BANG  TL
# 14  450  JAYSHREE  BANG  HR

# %%
df.loc[df["STATE"]=="BANG"]["CNAME"]
# Out:
# 10       RADHA
# 14    JAYSHREE
# Name: CNAME, dtype: object

# %%
# Number of peoples leaving in BANG
len(df.loc[df["STATE"]=="BANG"]["CNAME"])
# Out:
# 2

# %%
# Get Student Data set into DataFrame
df=pd.read_csv("D:\\Akash\\Python\\KVR-PYTHON-PART-1\\PANDAS\\NOTES\\Student.csv")
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
df["total"]=df["telugu"]+df["english"]+df["hindi"]+df["maths"]+df["science"]+df["social"]

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
df["percent"]=round((df["total"]/600)*100,2)

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  \
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
# Grading Rules
# Rule 1= perccent 100 --75--Distinction
# Rule 2=perccent 75 --65--First 
# Rule 3=perccent 65 --60--Second 
# Rule 4=perccent <60--Third

# %%
df["grade"]="Null"

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  \
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
df.loc[df["percent"]>=75]
# Out:
#     htno  name  telugu  english  hindi  maths  science  social  total  \
# 14   113  sonu      60       89     98     87       77      68    479
#
#     percent grade
# 14    79.83  Null

# %%
df.loc[df["percent"]>=75,["grade"]]="DISTINCION"

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  \
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
df.loc[df["grade"]=="DISTINCION"]
# Out:
#     htno  name  telugu  english  hindi  maths  science  social  total  \
# 14   113  sonu      60       89     98     87       77      68    479
#
#     percent       grade
# 14    79.83  DISTINCION

# %%
df.loc[((df["percent"]>=65)&(df["percent"]<75)),["grade"]]="FIRST"

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  \
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
df[df["grade"]=="FIRST"]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  \
# 0    100   Ramesh      50       60     66     98       66      55    395
# 2    102   Rossum      56       88     56     99       44      77    420
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# 13   112  shareef      50       63     99     90       76      67    445
# 16   115   Rakesh      67       78     88     78       67      49    427
#
#     percent  grade
# 0     65.83  FIRST
# 2     70.00  FIRST
# 6     67.67  FIRST
# 7     69.50  FIRST
# 8     65.00  FIRST
# 9     66.17  FIRST
# 10    65.00  FIRST
# ...

# %%
df[df["grade"]=="FIRST"][["htno","name"]]
# Out:
#     htno     name
# 0    100   Ramesh
# 2    102   Rossum
# 6    106   Kambli
# 7    107  Praveen
# 8    108   Ganesh
# 9    109     Nags
# 10   110    Biswa
# 11   111   Ritchi
# 13   112  shareef
# 16   115   Rakesh

# %%
len(df[df["grade"]=="FIRST"])
# Out:
# 10

# %%
df.loc[((df["percent"]>=60)&(df["percent"]<65)),["grade"]]="SECOND"

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  \
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
df.loc[(df["percent"]<60),["grade"]]="THIRD"

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  \
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
df.loc[df["grade"]=="THIRD"]
# Out:
#     htno    name  telugu  english  hindi  maths  science  social  total  \
# 1    101  Rajesh      45       67     34     67       66      78    357
# 15   114  Rajesh      45       67     77     55       66      46    356
#
#     percent  grade
# 1     59.50  THIRD
# 15    59.33  THIRD

# %%
# EXPORT DATA to DADtframe to csv fiile
df.to_csv("D:\\Akash\\Python\\KVR-PYTHON-PART-1\\PANDAS\\NOTES\\XthfinalResult.csv")

# %%
# EXPORT DATA to DADtframe to Excel fiile
df.to_excel("D:\\Akash\\Python\\KVR-PYTHON-PART-1\\PANDAS\\NOTES\\Xth.xlsx")
