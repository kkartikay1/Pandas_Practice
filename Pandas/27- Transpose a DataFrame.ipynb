# %%
import pandas as pd

# %%
emp=[[11,"Jack",44,"Sydney",19],[12,"Rita",41,"Delhi",17],[13,"Aadi",46,"Mumbai",11],
    [14,"Mothi",45,"Delhi",15],[15,"Veena",43,"Delhi",14],[16,"Shaunak",42,"Mumbai",17],
    [17,"Manik",42,"Sydney",14]]
df=pd.DataFrame(emp,columns=('ID','Name,','Age','City','Ecperience'),
                index=['a','b','c','d','e','f','g'])
print(df)
# Out:
#    ID    Name,  Age    City  Ecperience
# a  11     Jack   44  Sydney          19
# b  12     Rita   41   Delhi          17
# c  13     Aadi   46  Mumbai          11
# d  14    Mothi   45   Delhi          15
# e  15    Veena   43   Delhi          14
# f  16  Shaunak   42  Mumbai          17
# g  17    Manik   42  Sydney          14

# %%
# In this DataFrame provides an attribute T,
# and it t=returns the transpose version of the Dataframe
# Get transpose of DataFrame
tran=df.T
print(tran)
# Out:
#                  a      b       c      d      e        f       g
# ID              11     12      13     14     15       16      17
# Name,         Jack   Rita    Aadi  Mothi  Veena  Shaunak   Manik
# Age             44     41      46     45     43       42      42
# City        Sydney  Delhi  Mumbai  Delhi  Delhi   Mumbai  Sydney
# Ecperience      19     17      11     15     14       17      14
